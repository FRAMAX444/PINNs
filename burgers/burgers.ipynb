# %%
from utils import *

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def u_true_func(x):
    return -np.sin(np.pi * x)

x = np.linspace(-1, 1, 256, dtype=np.float32).squeeze()
t = np.linspace(0, 0.99, 100, dtype=np.float32).squeeze()

# %%
ps = PINNSolver([2, 50, 50, 50, 1], x, t)

# %%
ps.plot_initial_data()

# %%
ps.plot_training_points_1D()
# Out:
# c:\Users\frmar\OneDrive\Desktop\GitHub\PINNs\burgers\utils.py:87: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
ps.Train()
# Out:
# Epoch 0, Loss: 0.321348
# Epoch 500, Loss: 0.034252
# Epoch 1000, Loss: 0.014315
# Epoch 1500, Loss: 0.006805
# Epoch 2000, Loss: 0.003980
# Epoch 2500, Loss: 0.006776
# Epoch 3000, Loss: 0.001616
# Epoch 3500, Loss: 0.001195
# Epoch 4000, Loss: 0.001727
# Epoch 4500, Loss: 0.000768

# %%
ps.plot_solution()

# %%
ps.plot_predicted_slices_grid()
